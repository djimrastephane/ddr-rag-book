# %% [markdown]
# # Chapter 1 — Reading Your First DDR
#
# Interactive companion to `chapters/chapter_01.qmd`. Run the cells below in order.
#
# Before starting, generate the sample DDR archive from a terminal in the `book/` directory:
#
# ```bash
# python code/chapter_01/generate_sample_ddr.py
# ```

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "code" / "chapter_01"))

from read_ddr import extract_text

SAMPLE_DIR = Path.cwd().parent / "datasets" / "sample_ddrs"

# %%
pdf_path = SAMPLE_DIR / "DDR_017_EXAMPLE-1H.pdf"
text = extract_text(pdf_path)
print(text)

# %% [markdown]
# ## Try it yourself
#
# Extract text from `DDR_018_EXAMPLE-1H.pdf` below and confirm the stuck pipe event (`STK PIPE @ 9,960'`) appears in the output.

# %%
pdf_path = SAMPLE_DIR / "DDR_018_EXAMPLE-1H.pdf"
text = extract_text(pdf_path)
assert "STK PIPE" in text, "Expected to find the stuck pipe event in DDR 18"
print(text)
